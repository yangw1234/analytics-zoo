# %% [markdown]
# # Policy gradient algrorithm with BigDL

# %%
import random
import gym
import numpy as np
from collections import deque
import matplotlib.pyplot as plt

from bigdl.dataset.transformer import Sample
from bigdl.nn.layer import *
from bigdl.util.common import *
from bigdl.optim.optimizer import *
from bigdl.nn.criterion import *

init_engine()
# Out:
# Using /home/arsenior/Software/spark-1.6.3-bin-hadoop2.6
# Adding /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/bigdl/share/lib/bigdl-0.2.0-SNAPSHOT-jar-with-dependencies.jar to SPARK_CLASSPATH
# Prepending /home/arsenior/Software/anaconda3/lib/python3.5/site-packages/bigdl/share/conf/spark-bigdl.conf to sys.path

# %%
class PGAgent:
    def __init__(self, state_size, action_size, gamma=0.95, epsilon=1.0,
                 epsilon_min=0.01, epsilon_decay=0.995, learning_rate=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = gamma  # discount rate
        self.epsilon = epsilon  # exploration rate
        self.epsilon_min = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.learning_rate = learning_rate
        self.model = self._build_model()

    def _build_model(self):
        # Neural Net for Deep-Q learning Model
        model = Sequential()

        model.add(Linear(self.state_size, 24))
        model.add(ReLU())

        model.add(Linear(24, 24))
        model.add(ReLU())

        model.add(Linear(24, 1))
        return model

    def act(self, state):
        result = self.model.forward(state)
        return 0 if result < 0 else 1

# %%
def to_RDD(X, y):
    return sc.parallelize(X).zip(sc.parallelize(y)).map(
            lambda x: Sample.from_ndarray(x[0], x[1]))

# %%
import to_rdd

# %%
def play_n_games(n_games=100):
    memory = []
    actions = []
    results = np.array([])
    for e in range(n_games):
        state = env.reset()
        local_memory = np.array([0,0,0,0])
        local_actions = np.array([])
        for time in range(500):
            #env.render()
            local_memory = np.vstack((local_memory, state))
            action = agent.act(state)
            local_actions = np.append(local_actions, action)
            state, _, done, _ = env.step(action)
            if done or time == 498:
                memory.append(local_memory[1:])
                actions.append(local_actions)
                results = np.append(results, time)
                break
    return memory, actions, results

# %%
def games_to_train_data(memory, actions, results, benchmark):
    train_batch = np.array([0,0,0,0])
    train_labels = []
    for local_memory, local_actions, result in zip(memory, actions, results):
        train_batch = np.vstack((train_batch, np.array(local_memory)))
        if result > benchmark:
            local_labels = [-1 if x<=0 else 1 for x in local_actions]
        else:
            local_labels = [1 if x<=0 else -1 for x in local_actions]
        train_labels = np.append(train_labels, local_labels)
    return train_batch[1:], train_labels

# %%
env = gym.make('CartPole-v1')
conf = create_spark_conf()
conf.setMaster("local[1]")
sc = SparkContext.getOrCreate(conf)
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = PGAgent(state_size, action_size)
# Out:
# [2017-10-15 16:21:48,638] Making new env: CartPole-v1
# creating: createSequential
# creating: createLinear
# creating: createReLU
# creating: createLinear
# creating: createReLU
# creating: createLinear

# %%
record = []
i = 0
benchmark = 0
local_records = []

# %%
# %%time
t=0
while i <= 200:
    i += 1
    memory, actions, results = play_n_games(n_games=50)
    record.append((results.mean(), results.var()))
    print('Current resulst: {}, variance: {}. This is try number: {}'.format(results.mean(), results.var(), i))              
    benchmark = results.mean()
    train_batch, train_labels = games_to_train_data(memory, actions, results, benchmark)
    rdd_sample = to_rdd.to_RDD(train_batch, train_labels, sc)
    if benchmark != 498:
        t=0
        optimizer = Optimizer(model=agent.model,
                                  training_rdd=rdd_sample,
                                  criterion=MSECriterion(),
                                  optim_method=Adam(),
                                  end_trigger=MaxEpoch(1),
                                  batch_size=10)
        trained_model = optimizer.optimize()
        agent.model = trained_model
    else:
        t+=1
    if t==4:
        break
# Out:
# Current resulst: 8.32, variance: 0.4176. This is try number: 2
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 8.08, variance: 0.5536. This is try number: 3
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 8.5, variance: 0.49. This is try number: 4
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 8.4, variance: 0.5999999999999999. This is try number: 5
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 42.54, variance: 282.7684. This is try number: 6
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 8.34, variance: 0.5044. This is try number: 7
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 8.32, variance: 0.7376000000000001. This is try number: 8
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 9.2, variance: 11.24. This is try number: 9
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 12.38, variance: 3.4355999999999995. This is try number: 10
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 15.76, variance: 6.4624000000000015. This is try number: 11
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 40.76, variance: 50.062400000000004. This is try number: 12
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 51.58, variance: 73.12360000000001. This is try number: 13
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 38.82, variance: 38.1076. This is try number: 14
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 32.44, variance: 30.726399999999998. This is try number: 15
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 37.6, variance: 20.879999999999995. This is try number: 16
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 35.42, variance: 31.7636. This is try number: 17
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 33.44, variance: 19.1264. This is try number: 18
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 49.88, variance: 31.945600000000002. This is try number: 19
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 46.06, variance: 28.216400000000004. This is try number: 20
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 49.96, variance: 38.8384. This is try number: 21
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 36.38, variance: 25.6356. This is try number: 22
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 46.58, variance: 24.003600000000006. This is try number: 23
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 52.16, variance: 40.41439999999999. This is try number: 24
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 40.62, variance: 91.31560000000002. This is try number: 25
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 61.02, variance: 22.779600000000002. This is try number: 26
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 38.88, variance: 68.4256. This is try number: 27
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 37.54, variance: 41.1284. This is try number: 28
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 40.98, variance: 27.3796. This is try number: 29
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 49.36, variance: 31.790400000000005. This is try number: 30
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 46.08, variance: 74.9936. This is try number: 31
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 50.0, variance: 76.16. This is try number: 32
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 51.76, variance: 54.6224. This is try number: 33
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 54.0, variance: 43.68. This is try number: 34
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 52.26, variance: 48.5124. This is try number: 35
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 68.52, variance: 66.4096. This is try number: 36
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 408.5, variance: 23809.21. This is try number: 37
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 224.32, variance: 29708.4176. This is try number: 38
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 215.18, variance: 34301.6276. This is try number: 39
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 222.96, variance: 29231.358399999997. This is try number: 40
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 305.02, variance: 40701.3396. This is try number: 41
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 154.4, variance: 31473.680000000008. This is try number: 42
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 62.64, variance: 9684.8704. This is try number: 43
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 71.94, variance: 10577.216400000001. This is try number: 44
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 319.16, variance: 30110.7744. This is try number: 45
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 70.22, variance: 3368.4516. This is try number: 46
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 122.42, variance: 14162.723600000001. This is try number: 47
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 46.98, variance: 14139.059600000002. This is try number: 48
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 174.54, variance: 42573.68840000001. This is try number: 49
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 194.12, variance: 37333.6256. This is try number: 50
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 167.52, variance: 43574.8496. This is try number: 51
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 160.3, variance: 42509.40999999999. This is try number: 52
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 108.2, variance: 26932.92. This is try number: 53
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 146.94, variance: 24539.696400000004. This is try number: 54
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 83.98, variance: 23893.5396. This is try number: 55
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 297.7, variance: 32393.01. This is try number: 56
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 211.72, variance: 42798.5216. This is try number: 57
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 306.88, variance: 39424.545600000005. This is try number: 58
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 442.76, variance: 18563.262399999996. This is try number: 59
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 494.0, variance: 784.0. This is try number: 60
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 498.0, variance: 0.0. This is try number: 61
# Current resulst: 498.0, variance: 0.0. This is try number: 62
# Current resulst: 498.0, variance: 0.0. This is try number: 63
# Current resulst: 497.52, variance: 11.289600000000002. This is try number: 64
# creating: createMSECriterion
# creating: createAdam
# creating: createMaxEpoch
# creating: createOptimizer
# Current resulst: 498.0, variance: 0.0. This is try number: 65
# Current resulst: 498.0, variance: 0.0. This is try number: 66
# Current resulst: 498.0, variance: 0.0. This is try number: 67
# Current resulst: 498.0, variance: 0.0. This is try number: 68
# CPU times: user 31min 43s, sys: 6min 26s, total: 38min 10s
# Wall time: 1h 6min 17s

# %%
plt.plot([x[0] for x in record])
plt.show()

# %%
# %%time
_, _, res = play_n_games(n_games=100)
print(res)
# Out:
# [ 498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.  498.
#   498.  498.  498.  498.]
# CPU times: user 3min 8s, sys: 38.3 s, total: 3min 46s
# Wall time: 5min 11s
